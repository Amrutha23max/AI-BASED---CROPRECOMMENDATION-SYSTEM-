# %%
import os
print(os.getcwd())
# Out:
# C:\Users\amrut\Downloads\CROP_RECOMMENDATION

# %%
import os
print(os.listdir('.'))
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', '.virtual_documents', 'AI crop recommendation.drawio.png', 'app.py', 'class_indices.json', 'Crop_recommendation.csv', 'Initial Project Proposal Presentation (1).pptx', 'procfile', 'requirements.txt', 'soil classification.folder (1)', 'Untitled.ipynb', 'User flow AI crop recommendation.drawio.png', 'user-flowchart.md', 'workflow-flowchart.md']

# %%
import os
print(os.listdir('soil classification.folder (1)'))
# Out:
# ['test', 'train', 'valid']

# %%
import os

for split in ['train', 'valid', 'test']:
    path = f'soil classification.folder (1)/{split}'
    print(f"\n--- {split}/ ---")
    for cls in os.listdir(path):
        count = len(os.listdir(f'{path}/{cls}'))
        print(f"  {cls}: {count} images")
# Out:
# --- train/ ---
#   Black Soil: 177 images
#   Laterite Soil: 79 images
#   Yellow Soil: 73 images
#
# --- valid/ ---
#   Black Soil: 10 images
#   Laterite Soil: 6 images
#   Yellow Soil: 7 images
#
# --- test/ ---
#   Black Soil: 2 images
#   Laterite Soil: 2 images
#   Yellow Soil: 4 images

# %%
 
    
import os

for split in ['train', 'valid', 'test']:
    path = f'soil classification.folder (1)/{split}'
    print(f"\n--- {split}/ ---")
    for cls in os.listdir(path):
        count = len(os.listdir(f'{path}/{cls}'))
        print(f"  {cls}: {count} images")
# Out:
# --- train/ ---
#   Black Soil: 177 images
#   Laterite Soil: 79 images
#   Yellow Soil: 73 images
#
# --- valid/ ---
#   Black Soil: 10 images
#   Laterite Soil: 6 images
#   Yellow Soil: 7 images
#
# --- test/ ---
#   Black Soil: 27 images
#   Laterite Soil: 2 images
#   Yellow Soil: 4 images

# %%
import os

for split in ['train', 'valid', 'test']:
    path = f'soil classification.folder (1)/{split}'
    print(f"\n--- {split}/ ---")
    for cls in os.listdir(path):
        count = len(os.listdir(f'{path}/{cls}'))
        print(f"  {cls}: {count} images")
# Out:
# --- train/ ---
#   Black Soil: 177 images
#   Laterite Soil: 108 images
#   Yellow Soil: 73 images
#
# --- valid/ ---
#   Black Soil: 10 images
#   Laterite Soil: 6 images
#   Yellow Soil: 7 images
#
# --- test/ ---
#   Black Soil: 27 images
#   Laterite Soil: 2 images
#   Yellow Soil: 4 images

# %%
import requests
import os

base_folder = "downloaded_images"

# target classes (IMPORTANT)
target_folders = ["Black Soil", "Laterite Soil", "Yellow Soil"]

def download_images(api_url, current_folder=""):
    res = requests.get(api_url)

    if res.status_code != 200:
        print("Error:", res.status_code)
        return

    data = res.json()

    for file in data:
        if file['type'] == 'dir':
            folder_name = file['name']

            
            if folder_name in target_folders:
                new_path = os.path.join(base_folder, folder_name)
                os.makedirs(new_path, exist_ok=True)

                # Download images inside this folder
                download_images(file['url'], new_path)

            else:
                # Keep searching deeper
                download_images(file['url'], current_folder)

        elif file['type'] == 'file' and file['name'].endswith(('.jpg', '.png', '.jpeg')):
            if current_folder != "":
                img = requests.get(file['download_url']).content

                path = os.path.join(current_folder, file['name'])
                with open(path, 'wb') as f:
                    f.write(img)

                print("Downloaded:", path)


download_images("https://api.github.com/repos/Vishal-sys-code/AgroSense/contents/Datasets/Soil%20Image%20Dataset")

print("Done!")
# Out:
# Downloaded: downloaded_images\Black Soil\Black_1.jpg
# Downloaded: downloaded_images\Black Soil\Black_10.jpg
# Downloaded: downloaded_images\Black Soil\Black_11.jpg
# Downloaded: downloaded_images\Black Soil\Black_12.jpg
# Downloaded: downloaded_images\Black Soil\Black_13.jpg
# Downloaded: downloaded_images\Black Soil\Black_14.jpg
# Downloaded: downloaded_images\Black Soil\Black_15.jpg
# Downloaded: downloaded_images\Black Soil\Black_16.jpg
# Downloaded: downloaded_images\Black Soil\Black_17.jpg
# Downloaded: downloaded_images\Black Soil\Black_18.jpg
# Downloaded: downloaded_images\Black Soil\Black_19.jpg
# Downloaded: downloaded_images\Black Soil\Black_2.jpg
# Downloaded: downloaded_images\Black Soil\Black_20.jpg
# Downloaded: downloaded_images\Black Soil\Black_21.jpg
# Downloaded: downloaded_images\Black Soil\Black_22.jpg
# Downloaded: downloaded_images\Black Soil\Black_23.jpg
# Downloaded: downloaded_images\Black Soil\Black_24.jpg
# ...

# %%
import requests
import os

url = "https://api.github.com/repos/Vishal-sys-code/AgroSense/contents/Datasets/Soil%20Image%20Dataset/Train/Laterite%20Soil"
save_folder = "laterite_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done Laterite ✅")
# Out:
# Done Laterite ✅

# %%
import requests
import os

url = "https://api.github.com/repos/Vishal-sys-code/AgroSense/contents/Datasets/Soil%20Image%20Dataset/Train/Yellow%20Soil"
save_folder = "yellow_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done Yellow ")
# Out:
# Done Yellow

# %%
import os

for split in ['train', 'valid', 'test']:
    path = f'soil classification.folder (1)/{split}'
    print(f"\n--- {split}/ ---")
    for cls in os.listdir(path):
        count = len(os.listdir(f'{path}/{cls}'))
        print(f"  {cls}: {count} images")
# Out:
# --- train/ ---
#   Black Soil: 405 images
#   Laterite Soil: 108 images
#   Yellow Soil: 73 images
#
# --- valid/ ---
#   Black Soil: 10 images
#   Laterite Soil: 6 images
#   Yellow Soil: 7 images
#
# --- test/ ---
#   Black Soil: 27 images
#   Laterite Soil: 2 images
#   Yellow Soil: 4 images

# %%
pip install icrawler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(storage={'root_dir': 'yellow_soil'})

crawler.crawl(
    keyword='yellow soil',
    max_num=200
)
# Out:
# 2026-04-14 15:24:41,770 - INFO - icrawler.crawler - start crawling...
# 2026-04-14 15:24:41,772 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-04-14 15:24:41,778 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-04-14 15:24:41,781 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-04-14 15:24:44,258 - INFO - parser - parsing result page https://www.bing.com/images/async?q=yellow soil&first=0
# 2026-04-14 15:24:47,387 - INFO - downloader - image #1	https://as1.ftcdn.net/jpg/04/98/72/02/1000_F_498720261_TyZrD05HgVxa3n5WGpCTiP2Wt4v4XenH.jpg
# 2026-04-14 15:24:49,497 - INFO - downloader - image #2	https://thumbs.dreamstime.com/z/aerial-view-colorful-agricultural-fields-showcasing-different-crops-soil-types-under-clear-blue-sky-aerial-view-341058315.jpg
# ...

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(storage={'root_dir': 'laterite_soil'})

crawler.crawl(
    keyword='laterite soil',
    max_num=200
)
# Out:
# 2026-04-14 15:27:56,412 - INFO - icrawler.crawler - start crawling...
# 2026-04-14 15:27:56,414 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-04-14 15:27:56,417 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-04-14 15:27:56,421 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-04-14 15:27:58,317 - INFO - parser - parsing result page https://www.bing.com/images/async?q=laterite soil&first=0
# 2026-04-14 15:28:02,192 - INFO - downloader - image #1	https://www.shutterstock.com/shutterstock/photos/342863948/display_1500/stock-photo-tropical-laterite-soil-or-red-earth-background-red-mars-seamless-sand-background-top-view-342863948.jpg
# 2026-04-14 15:28:04,771 - INFO - downloader - image #2	https://thumbs.dreamstime.com/z/laterite-soil-tropical-red-earth-background-71802885.jpg
# 2026-04-14 15:28:04,850 - INFO - downloader - image #3	https://thumbs.dreamstime.com/b/laterite-soil-texture-red-gravel-floor-background-45027634.jpg
# ...

# %%
import os

for split in ['train', 'valid', 'test']:
    path = f'soil classification.folder (1)/{split}'
    print(f"\n--- {split}/ ---")
    for cls in os.listdir(path):
        count = len(os.listdir(f'{path}/{cls}'))
        print(f"  {cls}: {count} images")
# Out:
# --- train/ ---
#   Black Soil: 405 images
#   Laterite Soil: 148 images
#   Yellow Soil: 109 images
#
# --- valid/ ---
#   Black Soil: 10 images
#   Laterite Soil: 6 images
#   Yellow Soil: 7 images
#
# --- test/ ---
#   Black Soil: 27 images
#   Laterite Soil: 2 images
#   Yellow Soil: 4 images

# %%
import os, shutil

# Create new raw folder
os.makedirs('raw/Black Soil', exist_ok=True)
os.makedirs('raw/Laterite Soil', exist_ok=True)
os.makedirs('raw/Yellow Soil', exist_ok=True)

base = 'soil classification.folder (1)'

# Copy all images from train/valid/test into raw
for split in ['train', 'valid', 'test']:
    for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
        src = f'{base}/{split}/{cls}'
        dst = f'raw/{cls}'
        for i, fname in enumerate(os.listdir(src)):
            shutil.copy(f'{src}/{fname}', f'{dst}/{split}_{i}_{fname}')

# Verify
for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
    print(f"{cls}: {len(os.listdir(f'raw/{cls}'))}")
# Out:
# Black Soil: 442
# Laterite Soil: 156
# Yellow Soil: 120

# %%
import requests
import os

url = "https://api.github.com/repos/souvik0306/Soil-Type-Classification/contents/Soil%20types/Laterite%20Soil"
save_folder = "yellow_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done Yellow ")
# Out:
# Downloaded: Laterite_Soil_ (1).jpg
# Downloaded: Laterite_Soil_ (10).jpg
# Downloaded: Laterite_Soil_ (11).jpg
# Downloaded: Laterite_Soil_ (12).jpg
# Downloaded: Laterite_Soil_ (13).jpg
# Downloaded: Laterite_Soil_ (14).jpg
# Downloaded: Laterite_Soil_ (15).jpg
# Downloaded: Laterite_Soil_ (16).jpg
# Downloaded: Laterite_Soil_ (17).jpg
# Downloaded: Laterite_Soil_ (18).jpg
# Downloaded: Laterite_Soil_ (19).jpg
# Downloaded: Laterite_Soil_ (2).jpg
# Downloaded: Laterite_Soil_ (20).jpg
# Downloaded: Laterite_Soil_ (21).jpg
# Downloaded: Laterite_Soil_ (22).jpg
# Downloaded: Laterite_Soil_ (23).jpg
# Downloaded: Laterite_Soil_ (24).jpg
# Downloaded: Laterite_Soil_ (25).jpg
# Downloaded: Laterite_Soil_ (26).jpg
# Downloaded: Laterite_Soil_ (27).jpg
# Downloaded: Laterite_Soil_ (28).jpg
# Downloaded: Laterite_Soil_ (29).jpg
# Downloaded: Laterite_Soil_ (3).jpg
# Downloaded: Laterite_Soil_ (30).jpg
# Downloaded: Laterite_Soil_ (31).jpg
# Downloaded: Laterite_Soil_ (32).jpg
# ...

# %%
import requests
import os

url = "https://api.github.com/repos/souvik0306/Soil-Type-Classification/contents/Soil%20types/Yellow%20Soil"
save_folder = "yellow_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done Yellow ")
# Out:
# Downloaded: Yellow_Soil_ (1).jpg
# Downloaded: Yellow_Soil_ (10).jpg
# Downloaded: Yellow_Soil_ (11).jpg
# Downloaded: Yellow_Soil_ (12).jpg
# Downloaded: Yellow_Soil_ (13).jpg
# Downloaded: Yellow_Soil_ (14).jpg
# Downloaded: Yellow_Soil_ (15).jpg
# Downloaded: Yellow_Soil_ (16).jpg
# Downloaded: Yellow_Soil_ (17).jpg
# Downloaded: Yellow_Soil_ (18).jpg
# Downloaded: Yellow_Soil_ (19).jpg
# Downloaded: Yellow_Soil_ (2).jpg
# Downloaded: Yellow_Soil_ (20).jpg
# Downloaded: Yellow_Soil_ (21).jpg
# Downloaded: Yellow_Soil_ (22).jpg
# Downloaded: Yellow_Soil_ (23).jpg
# Downloaded: Yellow_Soil_ (24).jpg
# Downloaded: Yellow_Soil_ (25).jpg
# Downloaded: Yellow_Soil_ (26).jpg
# Downloaded: Yellow_Soil_ (27).jpg
# Downloaded: Yellow_Soil_ (28).jpg
# Downloaded: Yellow_Soil_ (29).jpg
# Downloaded: Yellow_Soil_ (3).jpg
# Downloaded: Yellow_Soil_ (30).jpg
# Downloaded: Yellow_Soil_ (31).jpg
# Downloaded: Yellow_Soil_ (32).jpg
# Downloaded: Yellow_Soil_ (33).jpg
# ...

# %%
import os, shutil

# Create new raw folder
os.makedirs('raw/Black Soil', exist_ok=True)
os.makedirs('raw/Laterite Soil', exist_ok=True)
os.makedirs('raw/Yellow Soil', exist_ok=True)

base = 'soil classification.folder (1)'

# Copy all images from train/valid/test into raw
for split in ['train', 'valid', 'test']:
    for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
        src = f'{base}/{split}/{cls}'
        dst = f'raw/{cls}'
        for i, fname in enumerate(os.listdir(src)):
            shutil.copy(f'{src}/{fname}', f'{dst}/{split}_{i}_{fname}')

# Verify
for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
    print(f"{cls}: {len(os.listdir(f'raw/{cls}'))}")
# Out:
# Black Soil: 442
# Laterite Soil: 216
# Yellow Soil: 178

# %%
import requests

url = "https://api.github.com/repos/Phantom-fs/Soil-Classification-Dataset/contents/CyAUG-Dataset/Laterite_Soil?ref=main"

res = requests.get(url)

print(res.status_code)
print(res.text[:200])  # debug

if res.status_code == 200:
    data = res.json()
    print("Success ")
else:
    print("Error ")
# Out:
# 200
# [{"name":"1.jpg","path":"CyAUG-Dataset/Laterite_Soil/1.jpg","sha":"b3a8d2065d5c1c965b743f3bfd1309f42bba507a","size":417927,"url":"https://api.github.com/repos/Phantom-fs/Soil-Classification-Dataset/co
# Success

# %%
import requests
import os

url = "https://api.github.com/repos/Phantom-fs/Soil-Classification-Dataset/contents/CyAUG-Dataset/Laterite_Soil?ref=main"
save_folder = "yellow_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done laterite")
# Out:
# Downloaded: 1.jpg
# Downloaded: 10.jpg
# Downloaded: 101.jpg
# Downloaded: 102.jpg
# Downloaded: 102a.jpg
# Downloaded: 103.jpg
# Downloaded: 104.jpg
# Downloaded: 106.jpg
# Downloaded: 108.jpg
# Downloaded: 108a.jpg
# Downloaded: 109.jpg
# Downloaded: 10a.jpg
# Downloaded: 11.jpg
# Downloaded: 110.jpg
# Downloaded: 111.jpg
# Downloaded: 114.jpg
# Downloaded: 114a.jpg
# Downloaded: 116.jpg
# Downloaded: 117.jpg
# Downloaded: 12.jpg
# Downloaded: 120.jpg
# Downloaded: 121.jpg
# Downloaded: 122.jpg
# Downloaded: 123.jpg
# Downloaded: 123a.jpg
# Downloaded: 124.jpg
# Downloaded: 125.jpg
# Downloaded: 127.jpg
# Downloaded: 128.jpg
# Downloaded: 128a.jpg
# Downloaded: 129.jpg
# Downloaded: 130.jpg
# Downloaded: 131.jpg
# Downloaded: 132.jpg
# Downloaded: 133.jpg
# Downloaded: 134.jpg
# Downloaded: 136.jpg
# Downloaded: 138.jpg
# Downloaded: 139.jpg
# Downloaded: 14.jpg
# Downloaded: 140.jpg
# Downloaded: 141.jpg
# Downloaded: 142.jpg
# Downloaded: 143.jpg
# Downloaded: 146.jpg
# ...

# %%
import os

url = "https://api.github.com/repos/Phantom-fs/Soil-Classification-Dataset/contents/CyAUG-Dataset/Yellow_Soil?ref=main"
import requests
save_folder = "yellow_soil"

os.makedirs(save_folder, exist_ok=True)

res = requests.get(url)

if res.status_code == 200:
    data = res.json()

    for file in data:
        if file['name'].endswith(('.jpg', '.png', '.jpeg')):
            img = requests.get(file['download_url']).content

            with open(os.path.join(save_folder, file['name']), 'wb') as f:
                f.write(img)

            print("Downloaded:", file['name'])

print("Done yellow")
# Out:
# Downloaded: 1.jpg
# Downloaded: 10.jpg
# Downloaded: 106.jpg
# Downloaded: 11.jpg
# Downloaded: 12.jpg
# Downloaded: 12a.jpg
# Downloaded: 12b.jpg
# Downloaded: 14.jpg
# Downloaded: 16.jpg
# Downloaded: 17.jpg
# Downloaded: 19.jpg
# Downloaded: 2.jpg
# Downloaded: 21.jpg
# Downloaded: 213.jpg
# Downloaded: 213a.jpg
# Downloaded: 213b.jpg
# Downloaded: 215.jpg
# Downloaded: 21a.jpg
# Downloaded: 22.jpg
# Downloaded: 22a.jpg
# Downloaded: 22b.jpg
# Downloaded: 23.jpg
# Downloaded: 24.jpg
# Downloaded: 25.jpg
# Downloaded: 25a.jpg
# Downloaded: 25b.jpg
# Downloaded: 26.jpg
# Downloaded: 27.jpg
# Downloaded: 30.jpg
# Downloaded: 33.jpg
# Downloaded: 34.jpg
# Downloaded: 35.jpg
# Downloaded: 36.jpg
# Downloaded: 37.jpg
# Downloaded: 39.jpg
# Downloaded: 4.jpg
# Downloaded: 40.jpg
# Downloaded: 41.jpg
# Downloaded: 41a.jpg
# Downloaded: 41b.jpg
# Downloaded: 41c.jpg
# Downloaded: 41d.jpg
# Downloaded: 41e.jpg
# Downloaded: 42.jpg
# Downloaded: 43.jpg
# Downloaded: 45.jpg
# ...

# %%
import os, shutil

# Create new raw folder
os.makedirs('raw/Black Soil', exist_ok=True)
os.makedirs('raw/Laterite Soil', exist_ok=True)
os.makedirs('raw/Yellow Soil', exist_ok=True)

base = 'soil classification.folder (1)'

# Copy all images from train/valid/test into raw
for split in ['train', 'valid', 'test']:
    for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
        src = f'{base}/{split}/{cls}'
        dst = f'raw/{cls}'
        for i, fname in enumerate(os.listdir(src)):
            shutil.copy(f'{src}/{fname}', f'{dst}/{split}_{i}_{fname}')

# Verify
for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
    print(f"{cls}: {len(os.listdir(f'raw/{cls}'))}")
# Out:
# Black Soil: 442
# Laterite Soil: 433
# Yellow Soil: 1251

# %%
import os, random

def cap_class(folder, max_count):
    files = os.listdir(folder)
    if len(files) > max_count:
        to_delete = random.sample(files, len(files) - max_count)
        for f in to_delete:
            os.remove(os.path.join(folder, f))
        print(f"Trimmed {folder} to {max_count} images")
    else:
        print(f"{folder} is fine at {len(files)} images")

cap_class('raw/Yellow Soil', 450)
cap_class('raw/Black Soil', 450)
cap_class('raw/Laterite Soil', 450)

# Verify
print("\nFinal counts:")
for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
    print(f"{cls}: {len(os.listdir(f'raw/{cls}'))}")
# Out:
# Trimmed raw/Yellow Soil to 450 images
# raw/Black Soil is fine at 442 images
# raw/Laterite Soil is fine at 433 images
#
# Final counts:
# Black Soil: 442
# Laterite Soil: 433
# Yellow Soil: 450

# %%
import os, shutil, random
from pathlib import Path

# Clean old dataset folder
if os.path.exists('dataset'):
    shutil.rmtree('dataset')

random.seed(42)

for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
    images = os.listdir(f'raw/{cls}')
    random.shuffle(images)
    
    total = len(images)
    train_end = int(0.7 * total)
    val_end = int(0.85 * total)
    
    splits = {
        'train': images[:train_end],
        'valid': images[train_end:val_end],
        'test':  images[val_end:]
    }
    
    for split, files in splits.items():
        dest = f'dataset/{split}/{cls}'
        os.makedirs(dest, exist_ok=True)
        for f in files:
            shutil.copy(f'raw/{cls}/{f}', f'{dest}/{f}')

# Verify
for split in ['train', 'valid', 'test']:
    print(f"\n--- {split}/ ---")
    for cls in ['Black Soil', 'Laterite Soil', 'Yellow Soil']:
        count = len(os.listdir(f'dataset/{split}/{cls}'))
        print(f"  {cls}: {count}")
# Out:
# --- train/ ---
#   Black Soil: 309
#   Laterite Soil: 303
#   Yellow Soil: 315
#
# --- valid/ ---
#   Black Soil: 66
#   Laterite Soil: 65
#   Yellow Soil: 67
#
# --- test/ ---
#   Black Soil: 67
#   Laterite Soil: 65
#   Yellow Soil: 68

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import json

print("TensorFlow version:", tf.__version__)
# Out:
# 2026-04-14 17:01:25,681 - INFO - numexpr.utils - NumExpr defaulting to 12 threads.
# TensorFlow version: 2.20.0

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS_HEAD = 20      # Phase 1: train only the head
EPOCHS_FINETUNE = 30  # Phase 2: fine-tune last 30 layers
TRAIN_DIR = 'dataset/train'
VAL_DIR   = 'dataset/valid'
TEST_DIR  = 'dataset/test'

# %%
# Augmentation for training only
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

# NO augmentation for val/test — only preprocessing
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True, seed=42
)
val_gen = val_datagen.flow_from_directory(
    VAL_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
test_gen = test_datagen.flow_from_directory(
    TEST_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

# Save class indices
with open('class_indices.json', 'w') as f:
    json.dump(train_gen.class_indices, f)
print("Classes:", train_gen.class_indices)
# Out:
# Found 927 images belonging to 3 classes.
# Found 198 images belonging to 3 classes.
# Found 200 images belonging to 3 classes.
# Classes: {'Black Soil': 0, 'Laterite Soil': 1, 'Yellow Soil': 2}

# %%
labels = train_gen.classes
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)
class_weight_dict = dict(enumerate(class_weights))
print("Class weights:", class_weight_dict)
# Out:
# Class weights: {0: np.float64(1.0), 1: np.float64(1.0198019801980198), 2: np.float64(0.9809523809523809)}

# %%
# Load MobileNetV3 base — frozen initially
base_model = MobileNetV3Large(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

# Build head
inputs = tf.keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.6)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
outputs = layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# ...
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ MobileNetV3Large (Functional)        │ (None, 7, 7, 960)           │       2,996,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 960)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

callbacks_phase1 = [
    ModelCheckpoint('best_soil_model_v3.h5', save_best_only=True,
                    monitor='val_accuracy', verbose=1),
    EarlyStopping(patience=5, restore_best_weights=True,
                  monitor='val_accuracy', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=3, verbose=1)
]

history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_HEAD,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase1
)
# Out:
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5550 - loss: 1.8732
# Epoch 1: val_accuracy improved from None to 0.86869, saving model to best_soil_model_v3.h5
# 2026-04-14 17:03:50,809 - WARNING - absl - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_soil_model_v3.h5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.6947 - loss: 1.5494 - val_accuracy: 0.8687 - val_loss: 1.1360 - learning_rate: 0.0010
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8633 - loss: 1.1884
# Epoch 2: val_accuracy improved from 0.86869 to 0.90404, saving model to best_soil_model_v3.h5
# ...

# %%
# Unfreeze last 30 layers of base model
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

# Recompile with lower LR
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

callbacks_phase2 = [
    ModelCheckpoint('best_soil_model_v3.h5', save_best_only=True,
                    monitor='val_accuracy', verbose=1),
    EarlyStopping(patience=7, restore_best_weights=True,
                  monitor='val_accuracy', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=3, verbose=1)
]

history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_FINETUNE,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8658 - loss: 1.0891
# Epoch 1: val_accuracy improved from None to 0.95960, saving model to best_soil_model_v3.h5
# 2026-04-14 17:12:37,372 - WARNING - absl - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_soil_model_v3.h5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8857 - loss: 1.0553 - val_accuracy: 0.9596 - val_loss: 0.8929 - learning_rate: 1.0000e-04
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 84s/step - accuracy: 0.8919 - loss: 0.9952
# Epoch 2: val_accuracy did not improve from 0.95960
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2361s 84s/step - accuracy: 0.8900 - loss: 1.0163 - val_accuracy: 0.9343 - val_loss: 0.9084 - learning_rate: 1.0000e-04
# ...

# %%
def plot_history(h1, h2):
    acc = h1.history['accuracy'] + h2.history['accuracy']
    val_acc = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    val_loss = h1.history['val_loss'] + h2.history['val_loss']

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Train Accuracy')
    plt.plot(val_acc, label='Val Accuracy')
    plt.axvline(len(h1.history['accuracy'])-1, color='gray',
                linestyle='--', label='Fine-tune start')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Train Loss')
    plt.plot(val_loss, label='Val Loss')
    plt.axvline(len(h1.history['loss'])-1, color='gray',
                linestyle='--', label='Fine-tune start')
    plt.title('Loss')
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_curves_v3.png')
    plt.show()

plot_history(history1, history2)

# %%
model.load_weights('best_soil_model_v3.h5')

loss, accuracy = model.evaluate(test_gen)
print(f"\nv3 Test accuracy: {accuracy*100:.2f}%")
print(f"v2 Test accuracy: 65.45%")
print(f"Improvement:      +{(accuracy*100 - 65.45):.2f}%")

from sklearn.metrics import classification_report
test_gen.reset()
preds = model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes
class_names = list(train_gen.class_indices.keys())
print("\nPer-class report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 584ms/step - accuracy: 0.9100 - loss: 0.9678
#
# v3 Test accuracy: 91.00%
# v2 Test accuracy: 65.45%
# Improvement:      +25.55%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step
#
# Per-class report:
#                precision    recall  f1-score   support
#
#    Black Soil       0.99      1.00      0.99        67
# Laterite Soil       0.79      0.98      0.88        65
#   Yellow Soil       1.00      0.75      0.86        68
#
#      accuracy                           0.91       200
#     macro avg       0.93      0.91      0.91       200
#  weighted avg       0.93      0.91      0.91       200
